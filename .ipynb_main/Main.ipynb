# %% [markdown]
# # ***Setup***

# %% [markdown]
# ### Mount the Drive

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Set the requirements

# %%
# !pip install -r /content/drive/MyDrive/benchmark/colab_requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 8.6 MB 6.1 MB/s
# ...
#      |████████████████████████████████| 431 kB 68.6 MB/s
# ...
#      |████████████████████████████████| 4.2 MB 55.6 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 53.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 91.3 MB/s
# ...
#      |████████████████████████████████| 101 kB 14.0 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %% [markdown]
# ### Unzip the datasets

# %%
# Create a copy of the datasets in the drive
# !sudo cp -v -r "/content/drive/MyDrive/datasets/" "/content/drive/MyDrive/datasets"
# Out:
# '/content/drive/MyDrive/datasets/' -> '/content/drive/MyDrive/datasets/datasets'
# cp: cannot copy a directory, '/content/drive/MyDrive/datasets/', into itself, '/content/drive/MyDrive/datasets/datasets'

# %%
# !unzip "/content/drive/MyDrive/datasets/tokyo-xs.zip" -d "/content/drive/MyDrive/datasets"

# %%
# !zip -r '/content/drive/MyDrive/datasets/mierda.zip' '/content/drive/MyDrive/datasets/tokyo_xs'

# %% [markdown]
# ### Checking if datasets have been imported correctly

# %%
# Check pitts30k size
! python3 /content/drive/MyDrive/benchmark/datasets_size.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k
# Out:
# The size of train data of pitts30k dataset is 17416
# The size of val data of pitts30k dataset is 17608
# The size of test data of pitts30k dataset is 16816

# %%
# Check sf_xs
! python3 /content/drive/MyDrive/benchmark/datasets_size.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs
# Out:
# The size of test data of sf_xs dataset is 28191

# %%
# Check tokyo_xs size
! python3 /content/drive/MyDrive/benchmark/datasets_size.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs
# Out:
# The size of test data of tokyo_xs dataset is 13095

# %%
# Check tokyo_night size 
! python3 /content/drive/MyDrive/benchmark/datasets_size.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night
# Out:
# The size of test data of tokyo_night dataset is 12876

# %% [markdown]
# # ***Train the model***

# %% [markdown]
# ### Original Model, Netvlad, 5 epochs

# %%
# Model trained with NetVLAD - 5 epoch 
# !python3 /content/drive/MyDrive/benchmark/train.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=5 --save_dir=/content/drive/MyDrive/trained_models
# Out:
# 2022-06-07 18:16:45   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=5, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume_compar=None, saturation=None
# ...

# %% [markdown]
# ### Original model, GeM 5 Epochs

# %%
# !python3 /content/drive/MyDrive/benchmark/train.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=5 --aggregation=gem --save_dir=/content/drive/MyDrive/trained_models
# Out:
# 2022-06-08 12:27:25   Arguments: Namespace(aggregation='gem', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=5, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume_compar=None, saturation=None, sa
# ...

# %% [markdown]
# ### Original model, GeM, 1 epoch

# %%
# Model trained with GeM - 1 epoch
# !python3 /content/drive/MyDrive/benchmark/train.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --aggregation=gem --save_dir=/content/drive/MyDrive/trained_models

# %% [markdown]
# # **Training Scheduler**

# %% [markdown]
# ### optim = adam - lr = 0.00001 - threshold = 0.005

# %%
# Model trained with NetVLAD - 5 epoch - lr = 0.00001 - threshold = 0.005
# !python3 /content/drive/MyDrive/benchmark/train_scheduler.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=5 --save_dir=/content/drive/MyDrive/trained_models --scheduler=plateau
# Out:
# 2022-06-18 13:31:24   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=5, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### optim = adam - lr = 0.001 - threshold = 0.005

# %%
# Model trained with NetVLAD - 5 epoch - lr=0.001 - threshold = 0.005
# !python3 /content/drive/MyDrive/benchmark/train_scheduler.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=5 --save_dir=/content/drive/MyDrive/trained_models --scheduler=plateau --lr 0.001
# Out:
# 2022-06-18 16:51:29   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=5, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### optim = adam - lr = 0.00001 - threshold = 0.01

# %%
# Model trained with NetVLAD - 5 epoch - lr = 0.00001 - threshold = 0.01
# !python3 /content/drive/MyDrive/benchmark/train_scheduler.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=5 --save_dir=/content/drive/MyDrive/trained_models --scheduler=plateau
# Out:
# 2022-06-19 07:40:19   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=5, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### PLATEAU: optim = asgd - lr = 0.1 - wd = 0.001 - threshold = 0.005

# %%
# Model trained with NetVLAD - 5 epoch - lr = 0.1 - threshold = 0.005 -optimizer=asgd - wd = 0.001
# !python3 /content/drive/MyDrive/benchmark/train_optim_sched.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=5 --save_dir=/content/drive/MyDrive/trained_models --scheduler=plateau --lr 0.1 --wd 0.001 --optim=asgd
# Out:
# 2022-06-21 12:59:23   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=5, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.1, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000
# ...

# %% [markdown]
# ###PLATEAU: optim = adamw - lr = 0.0001 - wd = 0.001 - threshold = 0.005

# %%
ç# Model trained with NetVLAD - 5 epoch - lr = 0.0001 - threshold = 0.005 -optimizer=adamw - wd = 0.001
# !python3 /content/drive/MyDrive/benchmark/train_optim_sched.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=5 --save_dir=/content/drive/MyDrive/trained_models --scheduler=plateau --lr 0.0001 --wd 0.001 --optim=adamw
# Out:
# 2022-06-22 10:27:33   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=5, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=
# ...

# %% [markdown]
# ### COSINE: optim = asgd - lr = 0.1 - wd = 0.001 - threshold = 0.005

# %%
# Model trained with NetVLAD - 5 epoch - lr = 0.1 - threshold = 0.005 -optimizer=asgd - wd = 0.001
# !python3 /content/drive/MyDrive/benchmark/train_optim_sched.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=5 --save_dir=/content/drive/MyDrive/trained_models --scheduler=cosine --lr 0.1 --wd 0.001 --optim=asgd
# Out:
# 2022-06-22 14:58:22   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=5, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.1, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000
# ...

# %% [markdown]
# ###COSINE: optim = adamw - lr = 0.0001 - wd = 0.001 - threshold = 0.005

# %%
# Model trained with NetVLAD - 5 epoch - lr = 0.0001 - threshold = 0.005 -optimizer=adamw - wd = 0.001
# !python3 /content/drive/MyDrive/benchmark/train_optim_sched.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=5 --save_dir=/content/drive/MyDrive/trained_models --scheduler=cosine --lr 0.0001 --wd 0.001 --optim=adamw
# Out:
# 2022-06-22 21:34:48   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=5, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=
# ...

# %% [markdown]
# # **Training Data Augmentation - Night robustness**

# %% [markdown]
# ## Color Jitter

# %% [markdown]
# ### 1 epoch - rand(0.2, 3)

# %%
# Model trained with NetVLAD - 1 epoch - Night Domain Adaptation - a = 0.2 - b = 3
# !python3 /content/drive/MyDrive/benchmark/train_augmented.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models
# Out:
# 2022-06-07 10:35:51   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume_compar=None, saturation=None
# ...

# %% [markdown]
# ### 1 epoch - rand(0, 1)

# %%
# Model trained with NetVLAD - 1 epoch - Night Domain Adaptation - a = 0 - b = 1
# !python3 /content/drive/MyDrive/benchmark/train_augmented.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models
# Out:
# 2022-06-07 13:40:00   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume_compar=None, saturation=None
# ...

# %% [markdown]
# ### 1 epoch - rand(0, 1) - inside

# %%
# Model trained with NetVLAD - 1 epoch - Night Domain Adaptation - a = 0 - b = 1 (inside)
# !python3 /content/drive/MyDrive/benchmark/train_augmented.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models
# Out:
# 2022-06-07 16:06:39   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume_compar=None, saturation=None
# ...

# %% [markdown]
# ### 1 epoch - (brightness, contast, saturation, hue) = (1,1,2,0)

# %%
# Model trained with NetVLAD - 1 epoch - Night Domain Adaptation - brightness 1 - contrast 1 -saturation = 2 - hue = 0
# !python3 /content/drive/MyDrive/benchmark/train.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models --brightness 1 --hue 0 --saturation 2 --contrast 1
# Out:
# 2022-06-08 18:41:30   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=1.0, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=1.0, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=0.0, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume=None, resume_compar=None, saturation=2.0, sa
# ...

# %% [markdown]
# ## Functional.adjust

# %% [markdown]
# ### brightness = 0.25

# %%
#  Model trained with NetVLAD - 1 epoch - Night Domain Adaptation - constant values of parameters
# !python3 /content/drive/MyDrive/benchmark/train_augmented_constant.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models
# Out:
# 2022-06-09 12:57:39   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, constant=False, contrast=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, re
# ...

# %% [markdown]
# ### brightness = 0.5

# %%
#  Model trained with NetVLAD - 1 epoch - Night Domain Adaptation - random constant number
# !python3 /content/drive/MyDrive/benchmark/train_augmented_constant.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models --bright_improv=0.5
# Out:
# 2022-06-09 19:24:16   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=0.5, brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, constant=False, contrast=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, rando
# ...

# %% [markdown]
# ### brightness = contrast = saturation = rand (0, 1) and hue = rand (0, 0.5)

# %%
# !python3 /content/drive/MyDrive/benchmark/train_augmented_constant.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models --brightness_r 1 --contrast_r 1 --saturation_r 1 --hue_r 0.5
# Out:
# 2022-06-10 16:14:03   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=1.0, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, constant=False, contrast=None, contrast_r=1.0, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, hue_r=0.5, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000, rand_per
# ...

# %% [markdown]
# ### brightness = contrast = saturation = rand(0, 2) and hue = rand(0, 0.5)

# %%
# !python3 /content/drive/MyDrive/benchmark/train_DA.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models --aggregation=gem --data_aug --night_robust --functional_adjust --brightness_r 2 --contrast_r 2 --saturation_r 2 --hue_r 0.5
# Out:
# 2022-06-11 10:35:14   Arguments: Namespace(aggregation='gem', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=2.0, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=2.0, criterion='triplet', data_aug=True, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=True, horizontal_flip=False, hue=None, hue_r=0.5, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=True, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000, rand_p
# ...

# %% [markdown]
# # **Training Data Augmentation - Perspective changes and occlusions robustness**

# %% [markdown]
# ## prob_RP = 0.33 - dist_scale = 0.4 - fill = 300 - prob_Eras = 0.33

# %%
# !python3 /content/drive/MyDrive/benchmark/train_RP_RE.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models --rand_perspective_dist 0.4 --rand_perspective_prob 0.33
# Out:
# 2022-06-11 17:03:38   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ## prob_RP = 0.5 - dist_scale = 0.2 - fill = 300 - prob_Eras = 0.2

# %%
# !python3 /content/drive/MyDrive/benchmark/train_RP_RE.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models --rand_perspective_dist 0.2 --rand_perspective_prob 0.5 --rand_erasing_prob 0.2 --rand_perspective_fill 300
# Out:
# 2022-06-12 09:51:51   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ## prob_RP = 0.33 - dist_scale = 0.4 - fill = 150 - prob_Eras = 0.33

# %%
# !python3 /content/drive/MyDrive/benchmark/train_RP_RE.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models --rand_perspective_dist 0.4 --rand_perspective_prob 0.33 --rand_erasing_prob 0.33 --rand_perspective_fill 150
# Out:
# 2022-06-12 12:32:28   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ## prob_RP = 0.5 - dist_scale = 0.2 - fill = 150 - prob_Eras = 0.2

# %%
# !python3 /content/drive/MyDrive/benchmark/train_RP_RE.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models --rand_perspective_dist 0.2 --rand_perspective_prob 0.5 --rand_erasing_prob 0.2 --rand_perspective_fill 150
# Out:
# 2022-06-12 14:32:52   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ## prob_RP = 0.33 - dist_scale = 0.4 - fill = 0 - prob_Eras = 0.33

# %%
# !python3 /content/drive/MyDrive/benchmark/train_RP_RE.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models --rand_perspective_dist 0.4 --rand_perspective_prob 0.33 --rand_erasing_prob 0.33 --rand_perspective_fill 0
# Out:
# 2022-06-12 15:45:32   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ## prob_RP = 0.5 - dist_scale = 0.2 - fill = 0 - prob_Eras = 0.2

# %%
# !python3 /content/drive/MyDrive/benchmark/train_RP_RE.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models --rand_perspective_dist 0.2 --rand_perspective_prob 0.5 --rand_erasing_prob 0.2 --rand_perspective_fill 0
# Out:
# 2022-06-12 16:51:49   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# #***Evaluation***

# %% [markdown]
# ### tokyo_xs

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45/best_model.pth --num_workers=4
# Out:
# python3: can't open file '/content/drive/MyDrive/benchmark/eval.py': [Errno 2] No such file or directory

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --aggregation=gem --resume=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --num_workers=4
# Out:
# python3: can't open file '/content/drive/MyDrive/benchmark/eval.py': [Errno 2] No such file or directory

# %% [markdown]
# ### tokyo_night

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45/best_model.pth --num_workers=4
# Out:
# python3: can't open file '/content/drive/MyDrive/benchmark/eval.py': [Errno 2] No such file or directory

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --aggregation=gem --resume=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --num_workers=4
# Out:
# python3: can't open file '/content/drive/MyDrive/benchmark/eval.py': [Errno 2] No such file or directory

# %% [markdown]
# ### sf_xs

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4
# Out:
# python3: can't open file '/content/drive/MyDrive/benchmark/eval.py': [Errno 2] No such file or directory

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --aggregation=gem --resume=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --num_workers=4
# Out:
# python3: can't open file '/content/drive/MyDrive/benchmark/eval.py': [Errno 2] No such file or directory

# %% [markdown]
# # ***Analysis Experiments***

# %% [markdown]
# ### Analysing feauture dimensions

# %%
#Resnet18 devuelve 256 feature dimension * 64 (nuumero de clusters)
! python3 /content/drive/MyDrive/benchmark/feature_analysis.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --resume=/content/drive/MyDrive/trained_models/2022-06-01_17-21-39/best_model.pth --num_workers=4
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/benchmark/feature_analysis.py", line 1, in <module>
#     import parser
#   File "/content/drive/MyDrive/benchmark/parser.py", line 3, in <module>
#     import torch
#   File "/usr/local/lib/python3.7/dist-packages/torch/__init__.py", line 199, in <module>
#     from torch._C import *  # noqa: F403
# RuntimeError: KeyboardInterrupt:

# %% [markdown]
# ### Analysing combination of models

# %%
# !python3 /content/drive/MyDrive/benchmark/ensamble_analysis.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --resume=/content/drive/MyDrive/trained_models/2022-06-01_17-21-39/best_model.pth --num_workers=4 --resume_compar=/content/drive/MyDrive/trained_models/2022-06-01_18-32-13/best_model.pth
# Out:
# Shape of NetVlad descriptors is (16, 16384)
# Shape of GeM descriptors is (16, 256)
# <class 'numpy.ndarray'>

# %% [markdown]
# # ***Evaluation with multiscale***

# %% [markdown]
# ## *Pitts30k*

# %% [markdown]
# ### Pitts30k Netvlad5Epochs

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --multi_scale_test
# Out:
# 2022-06-08 11:31:10   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=True, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_models/
# ...

# %% [markdown]
# ### Pitts30k GeM5Epochs

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --aggregation=gem --resume=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --num_workers=4 --multi_scale_test
# Out:
# 2022-06-08 15:11:14   Arguments: Namespace(aggregation='gem', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=True, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_models/2022
# ...

# %% [markdown]
# ## *tokyo_xs*

# %% [markdown]
# ### tokyo_xs Netvlad5Epochs

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --multi_scale_test
# Out:
# 2022-06-08 11:53:04   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=True, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_models/
# ...

# %% [markdown]
# ### tokyo_xs GeM5Epochs

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --aggregation=gem --resume=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --num_workers=4 --multi_scale_test
# Out:
# 2022-06-08 15:21:13   Arguments: Namespace(aggregation='gem', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=True, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_models/2022
# ...

# %% [markdown]
# ## *tokyo_night*

# %% [markdown]
# ### tokyo_night Netvlad 5Epochs

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --multi_scale_test
# Out:
# 2022-06-08 12:04:49   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=True, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_mode
# ...

# %% [markdown]
# ### tokyo_night GeM5Epochs

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --aggregation=gem --resume=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --num_workers=4 --multi_scale_test
# Out:
# 2022-06-08 15:24:32   Arguments: Namespace(aggregation='gem', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=True, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_models/2
# ...

# %% [markdown]
# ## *sf_xs*

# %% [markdown]
# ### sf_xs Netvlad 5Epochs

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --multi_scale_test
# Out:
# 2022-06-08 12:11:50   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=True, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_models/202
# ...

# %% [markdown]
# ### sf_xs GeM5Epochs

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --aggregation=gem --resume=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --num_workers=4 --multi_scale_test
# Out:
# 2022-06-08 15:15:25   Arguments: Namespace(aggregation='gem', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=True, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_models/2022-06
# ...

# %% [markdown]
# # ***Evaluation with concat ensambling***

# %% [markdown]
# ## Pitts30k

# %%
#Models 1 epoch
! python3 /content/drive/MyDrive/benchmark/eval_impr.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --resume=/content/drive/MyDrive/trained_models/2022-06-01_17-21-39/best_model.pth --num_workers=4 --comparison --resume_compar=/content/drive/MyDrive/trained_models/2022-06-01_18-32-13/best_model.pth --save_alt_dir=/content/drive/MyDrive/benchmark/logs_2/
# Out:
# 2022-06-07 07:52:23   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=True, contrast=None, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_models/
# ...

# %%
# Models with 5 epochs
! python3 /content/drive/MyDrive/benchmark/eval_impr.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --comparison --resume_compar=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --save_alt_dir=/content/drive/MyDrive/benchmark/logs_2/
# Out:
# 2022-06-08 15:31:00   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=True, contrast=None, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_models/
# ...

# %% [markdown]
# ## sf_xs

# %%
! python3 /content/drive/MyDrive/benchmark/eval_impr.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --comparison --resume_compar=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --save_alt_dir=/content/drive/MyDrive/benchmark/logs_2/
# Out:
# 2022-06-08 15:38:50   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=True, contrast=None, criterion='triplet', dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_models/202
# ...

# %% [markdown]
# ## tokyo_xs

# %%
! python3 /content/drive/MyDrive/benchmark/eval_impr.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --comparison --resume_compar=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --save_alt_dir=/content/drive/MyDrive/benchmark/logs_2/
# Out:
# 2022-06-08 15:47:09   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=True, contrast=None, criterion='triplet', dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_models/
# ...

# %% [markdown]
# ## tokyo_nights

# %%
! python3 /content/drive/MyDrive/benchmark/eval_impr.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --comparison --resume_compar=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --save_alt_dir=/content/drive/MyDrive/benchmark/logs_2/
# Out:
# 2022-06-08 15:52:19   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=True, contrast=None, criterion='triplet', dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_mode
# ...

# %% [markdown]
# # ***Evaluating Data Augmentation***

# %% [markdown]
# ## tokyo_xs

# %% [markdown]
# ### Color Jitter

# %% [markdown]
# #### Color Jitter - rand(0.2, 3)

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - a = 0.2 - b = 3
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_CJ_rand_0.2_3/best_model.pth --num_workers=4
# Out:
# 2022-06-11 11:00:44   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# #### Color Jitter - rand(0, 1)

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - a = 0 - b = 1
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_CJ_rand_0_1/best_model.pth --num_workers=4
# Out:
# 2022-06-11 11:27:09   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# #### Color Jitter - [br,cont, sat, hue] = (1,1,2,0)

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - saturation = 2 - brightness = 1 - hue = 0 - contrast = 1
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_CJ_1_1_2_0/best_model.pth --num_workers=4
# Out:
# 2022-06-11 11:53:39   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ### Functional adjust

# %% [markdown]
# #### Functional adjust - br = 0.25

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - constant brightness = 0.25
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_FA_0.25/best_model.pth --num_workers=4
# Out:
# 2022-06-11 12:09:17   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# #### Functional adjust - br = 0.5

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - constant brightness = 0.5
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_FA_0.5/best_model.pth --num_workers=4
# Out:
# 2022-06-11 12:22:49   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# #### Functional adjust - rand

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - rand
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_FA_rand/best_model.pth --num_workers=4
# Out:
# 2022-06-11 12:46:59   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ### RandomPerspective and RandomErasing

# %% [markdown]
# #### prob_RP = 0.33 - dist_scale = 0.4 - fill = 300 - prob_Eras = 0.33

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - rand
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl/best_model.pth --num_workers=4
# Out:
# 2022-06-11 19:49:20   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# #### prob_RP = 0.5 - dist_scale = 0.2 - fill = 300 - prob_Eras = 0.2

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_2/best_model.pth --num_workers=4
# Out:
# 2022-06-12 11:45:42   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# #### prob_RP = 0.33 - dist_scale = 0.4 - fill = 150 - prob_Eras = 0.33

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_3/best_model.pth --num_workers=4
# Out:
# 2022-06-12 13:39:52   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# #### prob_RP = 0.5 - dist_scale = 0.2 - fill = 150 - prob_Eras = 0.2

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_4/best_model.pth --num_workers=4
# Out:
# 2022-06-12 15:21:40   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# #### prob_RP = 0.33 - dist_scale = 0.4 - fill = 0 - prob_Eras = 0.33

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_5/best_model.pth --num_workers=4
# Out:
# 2022-06-12 16:36:50   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# #### prob_RP = 0.5 - dist_scale = 0.2 - fill = 0 - prob_Eras = 0.2

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_6/best_model.pth --num_workers=4
# Out:
# 2022-06-12 19:19:30   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ## sf_xs

# %% [markdown]
# ### Color Jitter

# %% [markdown]
# #### Color Jitter - rand(0.2, 3)

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - a = 0.2 - b = 3
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_CJ_rand_0.2_3/best_model.pth --num_workers=4
# Out:
# 2022-06-11 11:13:31   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# #### Color Jitter - rand(0, 1)

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - a = 0 - b = 1
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_CJ_rand_0_1/best_model.pth --num_workers=4
# Out:
# 2022-06-11 11:31:08   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# #### Color Jitter - [br,cont,sat,hue] = (1,1,2,0)

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - saturation = 2 - brightness = 1 - hue = 0 - contrast = 1
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_CJ_1_1_2_0/best_model.pth --num_workers=4
# Out:
# 2022-06-11 11:45:17   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### Functional adjust

# %% [markdown]
# #### Functional adjust - br = 0.25

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - constant brightness = 0.25
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_FA_0.25/best_model.pth --num_workers=4
# Out:
# 2022-06-11 11:59:17   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# #### Functional adjust - br = 0.5

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - constant brightness = 0.5
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_FA_0.5/best_model.pth --num_workers=4
# Out:
# 2022-06-11 12:16:02   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# #### Functional adjust - rand

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - rand
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_FA_rand/best_model.pth --num_workers=4
# Out:
# 2022-06-11 12:31:38   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### RandomPerspective and RandomErasing

# %% [markdown]
# #### prob_RP = 0.33 - dist_scale = 0.4 - fill = 300 - prob_Eras = 0.33

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl/best_model.pth --num_workers=4
# Out:
# 2022-06-11 19:40:43   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# #### prob_RP = 0.5 - dist_scale = 0.2 - fill = 300 - prob_Eras = 0.2

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_2/best_model.pth --num_workers=4
# Out:
# 2022-06-12 11:24:28   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# #### prob_RP = 0.33 - dist_scale = 0.4 - fill = 150 - prob_Eras = 0.33

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_3/best_model.pth --num_workers=4
# Out:
# 2022-06-12 13:11:21   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# #### prob_RP = 0.5 - dist_scale = 0.2 - fill = 150 - prob_Eras = 0.2

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_4/best_model.pth --num_workers=4
# Out:
# 2022-06-12 15:07:54   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# #### prob_RP = 0.33 - dist_scale = 0.4 - fill = 0 - prob_Eras = 0.33

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_5/best_model.pth --num_workers=4
# Out:
# 2022-06-12 16:21:59   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# #### prob_RP = 0.5 - dist_scale = 0.2 - fill = 0 - prob_Eras = 0.2

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_6/best_model.pth --num_workers=4
# Out:
# 2022-06-12 19:12:30   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ## tokyo_night

# %% [markdown]
# ### Color Jitter

# %% [markdown]
# #### Color Jitter - rand(0.2-3)

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - a = 0.2 - b = 3
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/2022-06-07_10-35-51/best_model.pth --num_workers=4
# Out:
# 2022-06-07 11:35:10   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_mod
# ...

# %% [markdown]
# #### Color Jitter - rand(0-1)

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - a = 0 - b = 1
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/2022-06-07_13-40-00/best_model.pth --num_workers=4
# Out:
# 2022-06-07 14:59:12   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_mod
# ...

# %% [markdown]
# #### Color Jitter - rand(0-1) inside

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - a = 0 - b = 1 (inside)
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/2022-06-07_16-06-39/best_model.pth --num_workers=4
# Out:
# 2022-06-07 16:41:15   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_mod
# ...

# %% [markdown]
# #### Color Jitter - [br,cont, sat, hue] = (1,1,2,0)

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - saturation = 2 - brightness = 1 - hue = 0 - contrast = 1
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/2022-06-08_18-41-30/best_model.pth --num_workers=4
# Out:
# 2022-06-08 20:50:09   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=False, contrast=None, criterion='triplet', dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640], resume='/content/drive/MyDrive/trained_mod
# ...

# %% [markdown]
# ### Functional adjust

# %% [markdown]
# #### Functional adjust - br = 0.25

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - constant brightness = 0.25
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/2022-06-09_12-57-39/best_model.pth --num_workers=4
# Out:
# 2022-06-09 14:04:05   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, constant=False, contrast=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=No
# ...

# %% [markdown]
# #### Functional adjust - br = 0.5

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - constant brightness = 0.5
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_FA_0.5/best_model.pth --num_workers=4
# Out:
# 2022-06-11 08:59:24   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, constant=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000,
# ...

# %% [markdown]
# #### Functional adjust - rand

# %%
# Evaluation Night queries with Night Adaption trained model (NetVLAD) - rand
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Night_FA_rand/best_model.pth --num_workers=4
# Out:
# 2022-06-11 09:11:15   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, constant=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000,
# ...

# %% [markdown]
# ### RandomPerspective and RandomErasing

# %% [markdown]
# #### prob_RP = 0.33 - dist_scale = 0.4 - fill = 300 - prob_Eras = 0.33

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl/best_model.pth --num_workers=4
# Out:
# 2022-06-11 20:12:25   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# #### prob_RP = 0.5 - dist_scale = 0.2 - fill = 300 - prob_Eras = 0.2

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_2/best_model.pth --num_workers=4
# Out:
# 2022-06-12 12:04:04   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# #### prob_RP = 0.33 - dist_scale = 0.4 - fill = 150 - prob_Eras = 0.33

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_3/best_model.pth --num_workers=4
# Out:
# 2022-06-12 14:12:32   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# #### prob_RP = 0.5 - dist_scale = 0.2 - fill = 150 - prob_Eras = 0.2

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_4/best_model.pth --num_workers=4
# Out:
# 2022-06-12 15:35:55   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# #### prob_RP = 0.33 - dist_scale = 0.4 - fill = 0 - prob_Eras = 0.33

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_5/best_model.pth --num_workers=4
# Out:
# 2022-06-12 16:43:26   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# #### prob_RP = 0.5 - dist_scale = 0.2 - fill = 0 - prob_Eras = 0.2

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/1epoch_DA_Persp_Ocl_6/best_model.pth --num_workers=4
# Out:
# 2022-06-12 20:48:16   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# # ***Evaluating ensambling with PCA***

# %% [markdown]
# ## PCA dim =2048

# %% [markdown]
# ### Pitts30k

# %%
! python3 /content/drive/MyDrive/benchmark/eval_impr.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --comparison --resume_compar=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --save_alt_dir=/content/drive/MyDrive/benchmark/logs_2/ --pca_dim=2048 --pca_dataset_folder=/content/drive/MyDrive/datasets/pitts30k/images/train
# Out:
# 2022-06-08 16:15:43   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=True, contrast=None, criterion='triplet', dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder='/content/drive/MyDrive/datasets/pitts30k/images/train', pca_dim=2048, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 6
# ...

# %% [markdown]
# ### sf_xs

# %%
! python3 /content/drive/MyDrive/benchmark/eval_impr.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --comparison --resume_compar=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --save_alt_dir=/content/drive/MyDrive/benchmark/logs_2/ --pca_dim=2048 --pca_dataset_folder=/content/drive/MyDrive/datasets/pitts30k/images/train
# Out:
# 2022-06-08 16:43:25   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=True, contrast=None, criterion='triplet', dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder='/content/drive/MyDrive/datasets/pitts30k/images/train', pca_dim=2048, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 640]
# ...

# %% [markdown]
# ### tokyo_xs

# %%
! python3 /content/drive/MyDrive/benchmark/eval_impr.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --comparison --resume_compar=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --save_alt_dir=/content/drive/MyDrive/benchmark/logs_2/ --pca_dim=2048 --pca_dataset_folder=/content/drive/MyDrive/datasets/pitts30k/images/train
# Out:
# 2022-06-08 17:10:07   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=True, contrast=None, criterion='triplet', dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder='/content/drive/MyDrive/datasets/pitts30k/images/train', pca_dim=2048, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480, 6
# ...

# %% [markdown]
# ### tokyo_night

# %%
! python3 /content/drive/MyDrive/benchmark/eval_impr.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/2022-06-07_18-16-45_Net5Epochs/best_model.pth --num_workers=4 --comparison --resume_compar=/content/drive/MyDrive/trained_models/2022-06-08_12-27-25_GeM5Epochs/best_model.pth --save_alt_dir=/content/drive/MyDrive/benchmark/logs_2/ --pca_dim=2048 --pca_dataset_folder=/content/drive/MyDrive/datasets/pitts30k/images/train
# Out:
# 2022-06-08 17:29:24   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', brightness=None, cache_refresh_rate=1000, channel_bottleneck=128, comparison=True, contrast=None, criterion='triplet', dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, horizontal_flip=False, hue=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder='/content/drive/MyDrive/datasets/pitts30k/images/train', pca_dim=2048, pretrain='imagenet', queries_per_epoch=5000, rand_perspective=None, random_resized_crop=None, random_rotation=None, recall_values=[1, 5, 10, 20], resize=[480
# ...

# %% [markdown]
# # ***Evaluating scheduler***

# %% [markdown]
# ## PLATEAU: optim = adam - lr = 0.00001 - threshold = 0.005

# %% [markdown]
# ### sf_xs

# %%
# Evaluation scheduler sf_xs - lr = 0.00001 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler/best_model.pth --num_workers=4
# Out:
# 2022-06-18 16:01:21   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### tokyo_xs

# %%
# Evaluation scheduler tokyo_xs - lr = 0.00001 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler/best_model.pth --num_workers=4
# Out:
# 2022-06-18 16:25:35   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ### tokyo_night

# %%
# Evaluation scheduler tokyo_night - lr = 0.00001 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler/best_model.pth --num_workers=4
# Out:
# 2022-06-18 19:34:02   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# ##PLATEAU: optim = adam - lr = 0.001 - threshold = 0.005

# %% [markdown]
# ### sf_xs

# %%
# Evaluation scheduler sf_xs - lr = 0.001 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_lr0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-18 19:01:29   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### tokyo_xs

# %%
# Evaluation scheduler tokyo_xs - lr = 0.001 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_lr0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-18 19:40:13   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ### tokyo_night

# %%
# Evaluation scheduler tokyo_night - lr = 0.001 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_lr0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-18 19:42:31   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# ## PLATEAU: optim = adam - lr = 0.00001 - threshold = 0.01

# %% [markdown]
# ### sf_xs

# %%
# Evaluation scheduler sf_xs - lr = 0.00001 - threshold = 0.01
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_lr0.00001_thr0.01/best_model.pth --num_workers=4
# Out:
# 2022-06-21 11:23:53   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### tokyo_xs

# %%
# Evaluation scheduler tokyo_xs - lr = 0.00001 - threshold = 0.01
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_lr0.00001_thr0.01/best_model.pth --num_workers=4
# Out:
# 2022-06-21 11:42:58   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ### tokyo_night

# %%
# Evaluation scheduler tokyo_night - lr = 0.00001 - threshold = 0.01
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_lr0.00001_thr0.01/best_model.pth --num_workers=4
# Out:
# 2022-06-21 11:46:26   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# ## PLATEAU: optim = ASGD - lr = 0.1 - threshold = 0.005 - wd = 0.01

# %% [markdown]
# ### sf_xs

# %%
# Evaluation scheduler ASGD - sf_xs - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_ASGD_lr0.1_wd0.01_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-22 08:47:07   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### tokyo_xs

# %%
# Evaluation scheduler ASGD - sf_xs - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_ASGD_lr0.1_wd0.01_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-22 09:06:27   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ### tokyo_night

# %%
# Evaluation scheduler ASGD - sf_xs - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_ASGD_lr0.1_wd0.01_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-22 09:15:37   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# ## PLATEAU: optim = ADAMW - lr = 0.0001 - threshold = 0.005 - wd = 0.01

# %% [markdown]
# ### sf_xs

# %%
# Evaluation scheduler ASGD - sf_xs - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_ADAMW_lr0.0001_wd0.01_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-22 14:09:49   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### tokyo_xs

# %%
# Evaluation scheduler ASGD - sf_xs - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_ADAMW_lr0.0001_wd0.01_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-22 14:15:54   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ### tokyo_night

# %%
# Evaluation scheduler ASGD - sf_xs - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_scheduler_ADAMW_lr0.0001_wd0.01_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-22 14:20:35   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# ## COSINE: optim = ASGD - lr = 0.1 - threshold = 0.005 - wd = 0.01

# %% [markdown]
# ### sf_xs

# %%
# Evaluation scheduler ASGD - sf_xs - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_schedulerCosine_ASGD_lr0.1_wd0.001_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-22 18:55:55   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### tokyo_xs

# %%
# Evaluation scheduler ASGD - tokyo_xs - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_schedulerCosine_ASGD_lr0.1_wd0.001_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-22 19:22:01   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ### tokyo_night

# %%
# Evaluation scheduler ASGD - tokyo_night - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_schedulerCosine_ASGD_lr0.1_wd0.001_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-22 19:26:18   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# ##COSINE: optim = adamw - lr = 0.0001 - wd = 0.001 - threshold = 0.005

# %% [markdown]
# ### sf_xs

# %%
# Evaluation scheduler ASGD - sf_xs - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_schedulerCosine_ADAMW_lr0.0001_wd0.001_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-23 07:30:18   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ### tokyo_xs

# %%
# Evaluation scheduler ASGD - tokyo_xs - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_schedulerCosine_ADAMW_lr0.0001_wd0.001_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-23 07:40:56   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ### tokyo_night

# %%
# Evaluation scheduler ASGD - tokyo_night - lr = 0.1 - wd = 0.01 - threshold = 0.005
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/5epochs_NetVLAD_schedulerCosine_ADAMW_lr0.0001_wd0.001_thr0.005/best_model.pth --num_workers=4
# Out:
# 2022-06-23 07:48:59   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# # ***Optimizer***

# %% [markdown]
# ## Training 1 epoch models

# %% [markdown]
# ### ASGD (lr=0.1, wd=0) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models --optim=asgd --lr=0.1 --wd=0
# Out:
# 2022-06-20 13:51:42   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.1, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=8, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000
# ...

# %% [markdown]
# ### ASGD (lr=0.01, wd=0) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=asgd --lr=0.01 --wd=0 --num_workers=4
# Out:
# 2022-06-20 14:31:05   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.01, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=500
# ...

# %% [markdown]
# ### ADAMW (lr=0.0001, wd=0.0001) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=adamw --lr=0.0001 --wd=0.0001 --num_workers=4
# Out:
# 2022-06-19 15:12:16   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=
# ...

# %% [markdown]
# ###ADAMW (lr=0.0001, wd=0.001) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=adamw --lr=0.0001 --wd=0.001 --num_workers=4
# Out:
# 2022-06-19 15:51:53   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=
# ...

# %% [markdown]
# ###ADAMW (lr=0.00001, wd=0.001) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=adamw --lr=0.00001 --wd=0.001 --num_workers=4
# Out:
# 2022-06-19 16:38:55   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5
# ...

# %% [markdown]
# ###ADAMW (lr=0.001, wd=0.001) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=adamw --lr=0.001 --wd=0.001 --num_workers=4
# Out:
# 2022-06-19 17:32:12   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5
# ...

# %% [markdown]
# ###ADAMW (lr=0.01, wd=0.001) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=adamw --lr=0.01 --wd=0.001 --num_workers=4
# Out:
# 2022-06-19 18:41:10   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.01, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ###ADAMW (lr=0.1, wd=0.001) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=adamw --lr=0.1 --wd=0.001 --num_workers=4
# Out:
# 2022-06-19 19:16:27   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.1, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=500
# ...

# %% [markdown]
# ###ADAMW (lr=0.0001, wd=0) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=adamw --lr=0.0001 --wd=0 --num_workers=4
# Out:
# 2022-06-19 19:54:18   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=
# ...

# %% [markdown]
# ###ADAMW (lr=0.0001, wd=0.1) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=adamw --lr=0.0001 --wd=0.1 --num_workers=4
# Out:
# 2022-06-19 20:38:10   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=
# ...

# %% [markdown]
# ### ADAMW (lr=0.0001, wd=0.01) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=adamw --lr=0.0001 --wd=0.01 --num_workers=4
# Out:
# 2022-06-19 21:17:27   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=
# ...

# %% [markdown]
# ###ASGD (lr=0.001, wd=0) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=asgd --lr=0.001 --wd=0 --num_workers=4
# Out:
# 2022-06-19 21:57:11   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ###ASGD (lr=0.0001, wd=0) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=asgd --lr=0.0001 --wd=0 --num_workers=4
# Out:
# 2022-06-20 07:13:03   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5
# ...

# %% [markdown]
# ###ASGD (lr=0.00001, wd=0) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=asgd --lr=0.00001 --wd=0 --num_workers=4
# Out:
# 2022-06-20 10:01:53   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ###ASGD (lr=0.1, wd=0.1) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=asgd --lr=0.1 --wd=0.1 --num_workers=4
# Out:
# 2022-06-20 11:27:44   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.1, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000
# ...

# %% [markdown]
# ###ASGD (lr=0.1, wd=0.01) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=asgd --lr=0.1 --wd=0.01 --num_workers=4
# Out:
# 2022-06-20 12:30:57   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.1, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000
# ...

# %% [markdown]
# ###ASGD (lr=0.1, wd=0.001) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=asgd --lr=0.1 --wd=0.001 --num_workers=4
# Out:
# 2022-06-20 13:11:02   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.1, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000
# ...

# %% [markdown]
# ###ASGD (lr=0.1, wd=0.0001) 1 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=1 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=asgd --lr=0.1 --wd=0.0001 --num_workers=4
# Out:
# 2022-06-20 15:09:40   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.1, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000
# ...

# %% [markdown]
# ## Training models 5 epochs

# %% [markdown]
# ### ADAMW (lr=0.0001, wd=0.001) 5 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=5 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=adamw --lr=0.0001 --wd=0.001 --num_workers=4
# Out:
# 2022-06-20 15:52:07   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=5, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.0001, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adamw', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=
# ...

# %% [markdown]
# ### ASGD (lr=0.1, wd=0.001) 5 epoch

# %%
! python3 /content/drive/MyDrive/benchmark/train_optim.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=pitts30k --epochs_num=5 --save_dir=/content/drive/MyDrive/trained_models/Optimizer_models --optim=asgd --lr=0.1 --wd=0.001 --num_workers=4
# Out:
# 2022-06-20 18:36:47   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='pitts30k', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=5, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=0.1, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='asgd', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=5000
# ...

# %% [markdown]
# ## Evaluating

# %% [markdown]
# ### ASGD 1 epoch lr=0.1 wd=0

# %%
# sf_xs
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/asgd_1epoch_lr0.1_wd0/best_model.pth --num_workers=4
# Out:
# 2022-06-19 13:22:49   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ###AGSD 1 epoch sf_xs (lr=0.1, 0.001)

# %%
# sf_xs
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/Optimizer_models/asgd_1epoch_lr0.1_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 08:38:59   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ###AGSD 1 epoch tokyo_xs (lr=0.1, 0.001)

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/Optimizer_models/asgd_1epoch_lr0.1_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 08:44:41   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ###AGSD 1 epoch tokyo_nights (lr=0.1, 0.001)

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/Optimizer_models/asgd_1epoch_lr0.1_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 08:56:55   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# ###AGSD 5 epoch sf_xs (lr=0.1, 0.001)

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/Optimizer_models/asgd_5epochs_lr0.1_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 09:10:30   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ###AGSD 5 epoch tokyo_xs (lr=0.1, 0.001)

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/Optimizer_models/asgd_5epochs_lr0.1_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 09:15:27   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ###AGSD 5 epoch tokyo_nights (lr=0.1, 0.001)

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/Optimizer_models/asgd_5epochs_lr0.1_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 09:18:05   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# ###ADAMW 1 epoch sf_xs (lr=0.0001, 0.001)

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/Optimizer_models/adamw_1epoch_lr0.0001_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 09:28:53   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ###ADAMW 1 epoch tokyo_xs (lr=0.0001, 0.001)

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/Optimizer_models/adamw_1epoch_lr0.0001_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 09:35:08   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ###ADAMW 1 epoch tokyo_nights (lr=0.0001, 0.001)

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/Optimizer_models/adamw_1epoch_lr0.0001_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 09:38:33   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...

# %% [markdown]
# ###ADAMW 5 epoch sf_xs (lr=0.0001, 0.001)

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=sf_xs --resume=/content/drive/MyDrive/trained_models/Optimizer_models/adamw_5epochs_lr0.0001_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 09:43:38   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='sf_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch=50
# ...

# %% [markdown]
# ###ADAMW 5 epoch tokyo_xs (lr=0.0001, 0.001)

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_xs --resume=/content/drive/MyDrive/trained_models/Optimizer_models/adamw_5epochs_lr0.0001_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 09:49:21   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_xs', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_epoch
# ...

# %% [markdown]
# ###ADAMW 5 epoch tokyo_nights (lr=0.0001, 0.001)

# %%
! python3 /content/drive/MyDrive/benchmark/eval.py --datasets_folder=/content/drive/MyDrive/datasets --dataset_name=tokyo_night --resume=/content/drive/MyDrive/trained_models/Optimizer_models/adamw_5epochs_lr0.0001_wd0.001/best_model.pth --num_workers=4
# Out:
# 2022-06-21 09:51:59   Arguments: Namespace(aggregation='netvlad', backbone='resnet18conv4', bright_improv=None, brightness=None, brightness_r=None, cache_refresh_rate=1000, channel_bottleneck=128, color_jitter=False, comparison=False, contrast=None, contrast_r=None, criterion='triplet', data_aug=False, dataset_name='tokyo_night', datasets_folder='/content/drive/MyDrive/datasets', device='cuda', efficient_ram_testing=False, epochs_num=1000, fc_output_dim=None, freeze_te=None, functional_adjust=False, horizontal_flip=False, hue=None, hue_r=None, infer_batch_size=16, l2='before_pool', lr=1e-05, lr_crn_layer=0.005, lr_crn_net=0.0005, majority_weight=0.01, margin=0.1, mining='partial', multi_scale_test=False, neg_samples_num=1000, negs_num_per_query=10, netvlad_clusters=64, night_robust=False, non_local=False, num_non_local=1, num_workers=4, off_the_shelf='imagenet', optim='adam', patience=3, pca_dataset_folder=None, pca_dim=None, pers_ocl_robust=False, pretrain='imagenet', queries_per_ep
# ...
